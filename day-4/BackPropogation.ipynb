# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([[8,8,4],[7,9,5],[6,10,6],[5,12,7]], columns = ["cgpa", "resume_score", "lpa"])

# %%
df
# Out:
#    cgpa  resume_score  lpa
# 0     8             8    4
# 1     7             9    5
# 2     6            10    6
# 3     5            12    7

# %%
def initialize_parameters(layers_dim):
  np.random.seed(3)
  parameters = {}
  L = len(layers_dim)
  for l in range(1, L):
    parameters['W' + str(l)] = np.ones((layers_dim[l - 1], layers_dim[l])) * 0.1
    parameters['B' + str(l)] = np.zeros((layers_dim[l],1))

  return parameters

# %%
initialize_parameters((2,2,1))
# Out:
# {'W1': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  'B1': array([[0.],
#         [0.]]),
#  'W2': array([[0.1],
#         [0.1]]),
#  'B2': array([[0.]])}

# %%
def linear_forward(A_prev, w, b):
  z = np.dot(w.T, A_prev) + b
  return z

# %%
def forward_propogation(X, parameters):
  A = X
  L = len(parameters)//2

  for l in range(1, L + 1):
    A_prev = A
    W1 = parameters['W' + str(l)]
    b1 = parameters['B' + str(l)]

    A = linear_forward(A_prev, W1, b1)

  return A, A_prev

# %%
X = df[['cgpa', 'resume_score']].values[0].reshape(2,1)
y = df[['lpa']].values[0][0]

parameters = initialize_parameters([2,2,1])

y_hat,A1 = forward_propogation(X, parameters)

# %%
(y - y_hat)**2
# Out:
# array([[13.5424]])

# %%
def update_parameters(parameters, y, y_hat, A1, x):
  parameters['W2'][0][0] += 0.01 * (2 * (y - y_hat) * A1[0][0])
  parameters['W2'][1][0] += 0.01 * (2 * (y - y_hat) * A1[1][0])
  parameters['B2'][0][0] += 0.01 * (2 * (y - y_hat))

  parameters['W1'][0][0] = parameters['W1'][0][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0]*X[0][0])
  parameters['W1'][0][1] = parameters['W1'][0][1] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0]*X[1][0])
  parameters['B1'][0][0] = parameters['B1'][0][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0])

  parameters['W1'][1][0] = parameters['W1'][1][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0]*X[0][0])
  parameters['W1'][1][1] = parameters['W1'][1][1] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0]*X[1][0])
  parameters['B1'][1][0] = parameters['B1'][1][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0])

# %%
update_parameters(parameters, y, y_hat, A1, X)
# Out:
# /tmp/ipykernel_503/3919738757.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W2'][0][0] += 0.01 * (2 * (y - y_hat) * A1[0][0])
# /tmp/ipykernel_503/3919738757.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W2'][1][0] += 0.01 * (2 * (y - y_hat) * A1[1][0])
# /tmp/ipykernel_503/3919738757.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['B2'][0][0] += 0.01 * (2 * (y - y_hat))
# /tmp/ipykernel_503/3919738757.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W1'][0][0] = parameters['W1'][0][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0]*X[0][0])
# /tmp/ipykernel_503/3919738757.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W1'][0][1] = parameters['W1'][0][1] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0]*X[1][0])
# /tmp/ipykernel_503/3919738757.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['B1'][0][0] = parameters['B1'][0][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0])
# /tmp/ipykernel_503/3919738757.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W1'][1][0] = parameters['W1'][1][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0]*X[0][0])
# /tmp/ipykernel_503/3919738757.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W1'][1][1] = parameters['W1'][1][1] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0]*X[1][0])
# /tmp/ipykernel_503/3919738757.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['B1'][1][0] = parameters['B1'][1][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0])

# %%
X = df[['cgpa', 'resume_score']].values[1].reshape(2,1)
y = df[['lpa']].values[1][0]

y_hat,A1 = forward_propogation(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,A1,X)

# %%
X = df[['cgpa', 'resume_score']].values[2].reshape(2,1)
y = df[['lpa']].values[2][0]

y_hat,A1 = forward_propogation(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,A1,X)

# %%
X = df[['cgpa', 'resume_score']].values[3].reshape(2,1)
y = df[['lpa']].values[3][0]

y_hat,A1 = forward_propogation(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,A1,X)
